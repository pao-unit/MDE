# %% [markdown]
# ## MDE Application to Fly Neural Data

# %% [markdown]
# ### Import modules
# Required modules are pyEDM, pandas & pyplot.

# %%
from pyEDM      import Simplex, ComputeError
from pandas     import read_csv, DataFrame
from matplotlib import pyplot as plt

# %% [markdown]
# These modules need to be available for the`Evaluate()`function to compare MDE results.

# %% [markdown]
# ```python
# import numpy
# import sklearn
# import pydiffmap
# ```

# %% [markdown]
# #### Import MDE & Evaluate classes

# %%
from dimx import MDE, Evaluate

# %% [markdown]
# ---

# %% [markdown]
# ### Drosophila melanogaster

# %% [markdown]
# A fly expressing the calcium indicator GCaMP6f as a measure of neuronal activity was
# recorded walking on a Styrofoam ball. Neuronal activity was segmented by independent
# component analysis (ICA) yielding 80 component brain areas. Two behavioral
# variables were simultaneously recorded: forward speed (FWD) and left/right turning
# speed (Left Right)

# %%
df = read_csv( '../data/Fly80XY_norm_1061.csv' )

# %% [markdown]
# #### Instantiate and Run MDE class objects for FWD & Left_Right targets
# We use the first 300 time series rows to create the EDM library, and perform out-of-sample prediction on time series rows 301-600. These indices are Not zero offset.
#
# `ccmSlope` is the minimum slope of a linear fit to the CCM rho(L) curve to validate a causal driver. L is the vector of CCM library sizes at which CCM is evaluated. Default values for L are percentiles [10,15,85,90] of the number of observations (rows).

# %%
df = read_csv( '../data/Fly80XY_norm_1061.csv' )

mde = MDE( df, target = 'FWD', 
           removeColumns = ['index','FWD','Left_Right'], 
           D = 10, lib = [1,300], pred = [301,600], ccmSeed = 12345,
           cores = 10, plot = True, title = "MDE FWD" )

mde.Run()

mde.MDEOut
# Out:
#   variables       rho
# 0      TS33  0.653000
# 1       TS4  0.792263
# 2      TS17  0.823037
# 3      TS71  0.840304
# 4      TS44  0.840540
# 5      TS37  0.844899
# 6       TS9  0.846607
# 7      TS30  0.859384
# 8      TS29  0.860016
# 9      TS67  0.865252

# %%
Fly_FWD = MDE( df,                     # Pandas DataFrame of observables
               target = 'FWD',         # target behavior variable
               removeColumns = ['index','FWD','Left_Right'], # variables to ignore
               D    = 12,              # Max number of dimensions
               lib  = [1,300],         # EDM library start,stop indices
               pred = [301,600],       # EDM prediction start,stop indices
               ccmSlope = 0.01,        # CCM convergence criteria
               embedDimRhoMin = 0.65,  # Minimum rho for CCM embedding dimension
               crossMapRhoMin = 0.5,   # Minumum rho for cross map of target : variables
               cores = 10,             # Number of cores in CrossMapColumns()
               chunksize = 30,
               plot = False,
               noCCM = False,
               ccmSeed = 12345,
               verbose=True)
Fly_FWD.Run()
# Out:
# Manifold Dimensional Expansion >------
#   2026-04-20 16:27:47.828909
# --------------------------------------------
#
# 1-D ['TS33'] rho 0.6529998799121696
# Timing 1-D: total 0.188s | cross map 0.018s | embed 0.017s | ccm 0.152s | other 0.001s
# 2-D ['TS33', 'TS4'] rho 0.7922634711791621
# Timing 2-D: total 0.213s | cross map 0.021s | embed 0.016s | ccm 0.175s | other 0.001s
# 3-D ['TS33', 'TS4', 'TS8'] rho 0.8186397118802091
# Timing 3-D: total 0.312s | cross map 0.020s | embed 0.110s | ccm 0.181s | other 0.002s
# 4-D ['TS33', 'TS4', 'TS8', 'TS9'] rho 0.8383245394454653
# Timing 4-D: total 0.248s | cross map 0.025s | embed 0.046s | ccm 0.176s | other 0.001s
# 5-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32'] rho 0.8588484588596922
# Timing 5-D: total 0.218s | cross map 0.025s | embed 0.016s | ccm 0.177s | other 0.001s
# 6-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24'] rho 0.859724092400424
# Timing 6-D: total 0.285s | cross map 0.023s | embed 0.077s | ccm 0.183s | other 0.002s
# 7-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26'] rho 0.867828180968037
# Timing 7-D: total 0.227s | cross map 0.024s | embed 0.016s | ccm 0.187s | other 0.001s
# 8-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26', 'TS71'] rho 0.8701924037533775
# Timing 8-D: total 0.206s | cross map 0.024s | embed 0.031s | ccm 0.150s | other 0.001s
# 9-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26', 'TS71', 'TS16'] rho 0.863458747410677
# Timing 9-D: total 0.265s | cross map 0.036s | embed 0.106s | ccm 0.121s | other 0.002s
# 10-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26', 'TS71', 'TS16', 'TS44'] rho 0.8584587249529781
# Timing 10-D: total 0.318s | cross map 0.026s | embed 0.107s | ccm 0.184s | other 0.002s
# 11-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26', 'TS71', 'TS16', 'TS44', 'TS23'] rho 0.8556619775070478
# Timing 11-D: total 0.283s | cross map 0.032s | embed 0.062s | ccm 0.187s | other 0.001s
# 12-D ['TS33', 'TS4', 'TS8', 'TS9', 'TS32', 'TS24', 'TS26', 'TS71', 'TS16', 'TS44', 'TS23', 'TS20'] rho 0.8513667773730238
# Timing 12-D: total 0.228s | cross map 0.033s | embed 0.016s | ccm 0.178s | other 0.001s
#
# Run() timing summary
#   total 2.995s | cross map 0.306s | embed 0.618s | ccm 2.051s | time delay 0.000s | other 0.035s
#   1-D candidates 80 ranked 9 ccm 1 | total 0.188s | cross map 0.018s | embed 0.017s | ccm 0.152s | other 0.001s
#   2-D candidates 79 ranked 78 ccm 1 | total 0.213s | cross map 0.021s | embed 0.016s | ccm 0.175s | other 0.001s
#   3-D candidates 78 ranked 78 ccm 1 | total 0.312s | cross map 0.020s | embed 0.110s | ccm 0.181s | other 0.002s
#   4-D candidates 77 ranked 77 ccm 1 | total 0.248s | cross map 0.025s | embed 0.046s | ccm 0.176s | other 0.001s
#   5-D candidates 76 ranked 76 ccm 1 | total 0.218s | cross map 0.025s | embed 0.016s | ccm 0.177s | other 0.001s
#   6-D candidates 75 ranked 75 ccm 1 | total 0.285s | cross map 0.023s | embed 0.077s | ccm 0.183s | other 0.002s
#   7-D candidates 74 ranked 74 ccm 1 | total 0.227s | cross map 0.024s | embed 0.016s | ccm 0.187s | other 0.001s
#   8-D candidates 73 ranked 73 ccm 1 | total 0.206s | cross map 0.024s | embed 0.031s | ccm 0.150s | other 0.001s
#   9-D candidates 72 ranked 72 ccm 1 | total 0.265s | cross map 0.036s | embed 0.106s | ccm 0.121s | other 0.002s
#   10-D candidates 71 ranked 71 ccm 1 | total 0.318s | cross map 0.026s | embed 0.107s | ccm 0.184s | other 0.002s
#   11-D candidates 70 ranked 70 ccm 1 | total 0.283s | cross map 0.032s | embed 0.062s | ccm 0.187s | other 0.001s
#   12-D candidates 69 ranked 69 ccm 1 | total 0.228s | cross map 0.033s | embed 0.016s | ccm 0.178s | other 0.001s
#
# Manifold Dimensional Expansion <------
#   Run() Elapsed time 0:00:02.994844
#   2026-04-20 16:27:50.826849
# --------------------------------------
#    variables       rho
# 0       TS33  0.653000
# 1        TS4  0.792263
# 2        TS8  0.818640
# 3        TS9  0.838325
# 4       TS32  0.858848
# 5       TS24  0.859724
# 6       TS26  0.867828
# 7       TS71  0.870192
# 8       TS16  0.863459
# 9       TS44  0.858459
# 10      TS23  0.855662
# 11      TS20  0.851367

# %%
Fly_LR = MDE( df,
              target = 'Left_Right',
              removeColumns = ['index','FWD','Left_Right'], 
              D    = 12,
              lib  = [1,600],
              pred = [801,1000], 
              ccmSlope = 0.01,
              embedDimRhoMin = 0.2,
              crossMapRhoMin = 0.05,
              cores = 10,
              chunksize = 30,
              plot = False,
              ccmSeed = 12345,
              verbose = True )
Fly_LR.Run()
# Out:
# Manifold Dimensional Expansion >------
#   2026-04-20 16:28:22.183915
# --------------------------------------------
#
# 1-D ['TS9'] rho 0.48610116611340703
# Timing 1-D: total 0.160s | cross map 0.036s | embed 0.020s | ccm 0.103s | other 0.001s
# 2-D ['TS9', 'TS79'] rho 0.6421246621090569
# Timing 2-D: total 0.257s | cross map 0.023s | embed 0.044s | ccm 0.189s | other 0.001s
# 3-D ['TS9', 'TS79', 'TS53'] rho 0.6943661568756355
# Timing 3-D: total 0.172s | cross map 0.021s | embed 0.015s | ccm 0.135s | other 0.001s
# 4-D ['TS9', 'TS79', 'TS53', 'TS67'] rho 0.7040593398494732
# Timing 4-D: total 0.162s | cross map 0.021s | embed 0.015s | ccm 0.125s | other 0.001s
# 5-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35'] rho 0.7365173182615519
# Timing 5-D: total 0.222s | cross map 0.022s | embed 0.016s | ccm 0.184s | other 0.001s
# 6-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65'] rho 0.7410143015694561
# Timing 6-D: total 0.259s | cross map 0.025s | embed 0.088s | ccm 0.144s | other 0.002s
# 7-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69'] rho 0.7501388660563358
# Timing 7-D: total 0.237s | cross map 0.026s | embed 0.057s | ccm 0.153s | other 0.001s
# 8-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69', 'TS56'] rho 0.7636434796031172
# Timing 8-D: total 0.161s | cross map 0.026s | embed 0.030s | ccm 0.104s | other 0.001s
# 9-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69', 'TS56', 'TS60'] rho 0.7701640373669134
# Timing 9-D: total 0.227s | cross map 0.031s | embed 0.016s | ccm 0.179s | other 0.001s
# 10-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69', 'TS56', 'TS60', 'TS71'] rho 0.7738247616718987
# Timing 10-D: total 0.269s | cross map 0.030s | embed 0.058s | ccm 0.179s | other 0.001s
# 11-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69', 'TS56', 'TS60', 'TS71', 'TS39'] rho 0.7419895899405022
# Timing 11-D: total 0.319s | cross map 0.030s | embed 0.103s | ccm 0.185s | other 0.002s
# 12-D ['TS9', 'TS79', 'TS53', 'TS67', 'TS35', 'TS65', 'TS69', 'TS56', 'TS60', 'TS71', 'TS39', 'TS26'] rho 0.7285735410294952
# Timing 12-D: total 0.221s | cross map 0.030s | embed 0.045s | ccm 0.145s | other 0.001s
#
# Run() timing summary
#   total 2.668s | cross map 0.319s | embed 0.507s | ccm 1.825s | time delay 0.000s | other 0.032s
#   1-D candidates 80 ranked 17 ccm 1 | total 0.160s | cross map 0.036s | embed 0.020s | ccm 0.103s | other 0.001s
#   2-D candidates 79 ranked 74 ccm 1 | total 0.257s | cross map 0.023s | embed 0.044s | ccm 0.189s | other 0.001s
#   3-D candidates 78 ranked 72 ccm 1 | total 0.172s | cross map 0.021s | embed 0.015s | ccm 0.135s | other 0.001s
#   4-D candidates 77 ranked 71 ccm 1 | total 0.162s | cross map 0.021s | embed 0.015s | ccm 0.125s | other 0.001s
#   5-D candidates 76 ranked 71 ccm 1 | total 0.222s | cross map 0.022s | embed 0.016s | ccm 0.184s | other 0.001s
#   6-D candidates 75 ranked 71 ccm 1 | total 0.259s | cross map 0.025s | embed 0.088s | ccm 0.144s | other 0.002s
#   7-D candidates 74 ranked 70 ccm 1 | total 0.237s | cross map 0.026s | embed 0.057s | ccm 0.153s | other 0.001s
#   8-D candidates 73 ranked 69 ccm 1 | total 0.161s | cross map 0.026s | embed 0.030s | ccm 0.104s | other 0.001s
#   9-D candidates 72 ranked 68 ccm 1 | total 0.227s | cross map 0.031s | embed 0.016s | ccm 0.179s | other 0.001s
#   10-D candidates 71 ranked 67 ccm 1 | total 0.269s | cross map 0.030s | embed 0.058s | ccm 0.179s | other 0.001s
#   11-D candidates 70 ranked 66 ccm 1 | total 0.319s | cross map 0.030s | embed 0.103s | ccm 0.185s | other 0.002s
#   12-D candidates 69 ranked 65 ccm 1 | total 0.221s | cross map 0.030s | embed 0.045s | ccm 0.145s | other 0.001s
#
# Manifold Dimensional Expansion <------
#   Run() Elapsed time 0:00:02.668198
#   2026-04-20 16:28:24.855309
# --------------------------------------
#    variables       rho
# 0        TS9  0.486101
# 1       TS79  0.642125
# 2       TS53  0.694366
# 3       TS67  0.704059
# 4       TS35  0.736517
# 5       TS65  0.741014
# 6       TS69  0.750139
# 7       TS56  0.763643
# 8       TS60  0.770164
# 9       TS71  0.773825
# 10      TS39  0.741990
# 11      TS26  0.728574

# %% [markdown]
# #### Combine FWD & Left_Right results to DataFrame and plot

# %%
FlyDF = DataFrame( 
    {'D' : [i for i in range(1, len(Fly_FWD.MDEOut)+1)],
     'FWD_variable':Fly_FWD.MDEOut['variables'], 'FWD_rho':Fly_FWD.MDEOut['rho'], 
     'LR_variable' :Fly_LR.MDEOut['variables'],  'LR_rho' :Fly_LR.MDEOut['rho'] } )

# %%
ax = FlyDF.plot( x = 'D', y=['FWD_rho','LR_rho'], label = ['FWD','Left_Right'],
                 lw = 3, figsize = (5,4), title = 'Fly MDE' )
table = ax.table( cellText = FlyDF.loc[:,['D','FWD_variable','LR_variable']].values,
                  colLabels = ['D','FWD','LR'], loc = 'lower center', fontsize = 10,
                  colWidths = [0.1,0.12,0.12], edges = 'open', colLoc = 'left', cellLoc = 'left' )

# %% [markdown]
# #### Evaluate MDE components & compare to PCA & Diffusion Map

# %%
Fly_FWD_Eval = Evaluate( df, 
                         columns_range = [1,81], # 0-offset range of columns for PCA, DMap
                         mde_columns = ['TS33', 'TS4', 'TS8', 'TS9', 'TS32'],
                         predictVar = 'FWD',
                         library    = [1, 300],   # index start,stop of observations for library
                         prediction = [301, 600], # index start,stop of predictions 
                         components = 5,          # Number of PCA & DMap components
                         dmap_k     = 15,         # diffusion_map k nearest neighbors
                         figsize    = (8,6) )
Fly_FWD_Eval.Run()
Fly_FWD_Eval.Plot()
# Out:
# 	MDE:  CAE 35.37  RMSE 0.183  R 0.85  R^2 0.722
# 	PCA:  CAE 53.25  RMSE 0.212  R 0.802  R^2 0.643
# 	dMap: CAE 47.24  RMSE 0.219  R 0.77  R^2 0.593

# %% [markdown]
# ---

# %% [markdown]
# #### MDE Arguments
#
# | Parameter | Default | Description |
# |---|---|---|
# | dataFrame | None | Pandas DataFrame : column observation vectors, row observations |
# | dataFile | None | Data file name to load |
# | dataName | None | Data name in .npz archive |
# | removeTime | False | Remove first column from dataFrame |
# | noTime | False | First column of dataFrame is not time vector |
# | columnNames | [] | dataFrame columns to process |
# | initDataColumns | [] | If reading .npz omit these leading columns |
# | removeColumns | [] | Columns to ignore |
# | D | 3 | Maximum number of MDE dimensions |
# | target | None | Target variable |
# | lib | [] | EDM library indices. Default to all rows |
# | pred | [] | EDM prediction indices. Default to all rows  |
# | Tp | 1 | Prediction time interval |
# | tau | -1 | CCM embedding time delay |
# | exclusionRadius | 0 | CCM library temporal exlcusion radius |
# | sample | 20 | CCM random library samples to average |
# | pLibSizes | [10, 15, 85, 90] | Percentiles of CCM library sizes |
# | noCCM | False | Disable CCM |
# | ccmSlope | 0.01 | Slope of CCM(LibSizes) convergence |
# | ccmSeed | None | CCM random seed |
# | E | 0 | CCM embedding dimension. If 0 compute automatically |
# | crossMapRhoMin | 0.5 | Minimum rho for cross map acceptance |
# | embedDimRhoMin | 0.5 | Minimum rho for CCM embedding dimension |
# | maxE | 15 | Maximum embedding dimension for CCM |
# | firstEMax | False | CCM embedding dimension is first local peak in rho(E) |
# | timeDelay | 0 | Add N=timeDelay time delays |
# | cores | 5 | number of multiprocessing CPU in CrossMapColumns() |
# | outDir | None | Output file directory |
# | outFile | None | MDE object pickle file |
# | outCSV | None | CSV of MDE output |
# | logFile | None | Log file |
# | consoleOut | True | Echo output to console |
# | verbose | False | Verbose mode |
# | debug | False | Debug mode |
# | plot | False | Plot MDE result |
# | title | None | Plot title |
# | args | None | ArgumentParser object from CLI_Parser |
